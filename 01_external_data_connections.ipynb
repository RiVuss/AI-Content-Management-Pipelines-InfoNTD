# %% [markdown]
# # Connecting to crossref, pubmed and others
# ## Imports

# %%
from datasets import load_dataset
import csv
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# ## Downloading Pubmed

# %%
# Stream the dataset
dataset = load_dataset("Datasets/pubmed.py", streaming=True,split='train')

# %%
first_example = next(iter(dataset))
print(first_example)
# Out:
# {'MedlineCitation': {'PMID': 1, 'DateCompleted': {'Year': 1976, 'Month': 1, 'Day': 16}, 'NumberOfReferences': 0, 'DateRevised': {'Year': 2024, 'Month': 1, 'Day': 9}, 'Article': {'Abstract': {'AbstractText': ''}, 'ArticleTitle': 'Formate assay in body fluids: application in methanol poisoning.', 'AuthorList': {'Author': {'LastName': ['Makar', 'McMartin', 'Palese', 'Tephly'], 'ForeName': ['A B', 'K E', 'M', 'T R'], 'Initials': ['AB', 'KE', 'M', 'TR'], 'CollectiveName': ['', '', '', '']}}, 'Language': 'eng', 'GrantList': {'Grant': {'GrantID': ['F32 AG064886', 'MC_UU_12013/5'], 'Agency': ['NIA NIH HHS', 'MRC'], 'Country': ['United States', 'United Kingdom']}}, 'PublicationTypeList': {'PublicationType': ['Journal Article', "Research Support, U.S. Gov't, P.H.S."]}}, 'MedlineJournalInfo': {'Country': 'United States'}, 'ChemicalList': {'Chemical': {'RegistryNumber': ['0', '142M471B3J', 'EC 1.2.-', 'Y4S76JWI15'], 'NameOfSubstance': ['Formates', 'Carbon Dioxide', 'Aldehyde Oxidoreductases', 'Methanol']}}, 'CitationSubset': 'IM', 'MeshHeadingList': {'MeshHeading': {'DescriptorName': ['Aldehyde Oxidoreductases', 'Animals', 'Body Fluids', 'Carbon Dioxide', 'Formates', 'Haplorhini', 'Humans', 'Hydrogen-Ion Concentration', 'Kinetics', 'Methanol', 'Methods', 'Pseudomonas'], 'QualifierName': ['metabolism', '', 'analysis', 'blood', 'blood', '', '', '', '', 'blood', '', 'enzymology']}}}, 'PubmedData': {'ArticleIdList': {'ArticleId': [[], ['1', '10.1016/0006-2944(75)90147-7']]}, 'PublicationStatus': 'ppublish', 'History': {'PubMedPubDate': {'Year': [1975, 1975, 1975], 'Month': [6, 6, 6], 'Day': [1, 1, 1]}}, 'ReferenceList': {'Citation': [], 'CitationId': []}}}

# %%
output_file = "H:/Datasets/pubmed_since_2005.csv"
fieldnames = [
    "pmid", "title", "abstract", "authors", "language", "year", "month",
    "publication_type", "country", "agency", "mesh_terms", "doi"
]

def get_first_doi(article_id_list):
    try:
        return article_id_list["ArticleId"][1][1]
    except:
        return ""

def get_year(example):
    try:
        return int(example["MedlineCitation"]["DateCompleted"]["Year"])
    except:
        return 0

stream = iter(dataset)
row_count = 0
skipped_rows = 0

with open(output_file, mode="w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

    with tqdm(total=32_500_000, desc="Streaming PubMed", unit="records") as pbar:
        while True:
            try:
                example = next(stream)
                pbar.update(1)
            except StopIteration:
                break
            except Exception:
                continue  # skip broken rows

            year = get_year(example)

            # Heuristic skipping
            if year < 2005:
                if year < 1995:
                    skip_n = 50
                elif year < 2000:
                    skip_n = 5
                else:
                    skip_n = 10

                for _ in range(skip_n):
                    try:
                        next(stream)
                        pbar.update(1)
                        skipped_rows += 1
                    except:
                        break
                continue

            citation = example.get("MedlineCitation", {})
            article = citation.get("Article", {})
            pubmed_data = example.get("PubmedData", {})

            # Extract fields
            pmid = citation.get("PMID", "")
            title = article.get("ArticleTitle", "")
            abstract = article.get("Abstract", {}).get("AbstractText", "")
            language = article.get("Language", "")
            doi = get_first_doi(pubmed_data.get("ArticleIdList", {}))

            date_completed = citation.get("DateCompleted", {})
            month = date_completed.get("Month", "")

            authors_raw = article.get("AuthorList", {}).get("Author", {})
            last_names = authors_raw.get("LastName", [])
            fore_names = authors_raw.get("ForeName", [])
            authors = [f"{fn} {ln}" for fn, ln in zip(fore_names, last_names)]

            mesh = citation.get("MeshHeadingList", {}).get("MeshHeading", {})
            mesh_terms = mesh.get("DescriptorName", []) if isinstance(mesh, dict) else []

            publication_type = article.get("PublicationTypeList", {}).get("PublicationType", [])
            publication_type_str = "; ".join(publication_type)

            country = citation.get("MedlineJournalInfo", {}).get("Country", "")

            grant = article.get("GrantList", {}).get("Grant", {})
            agencies = grant.get("Agency", []) if isinstance(grant, dict) else []
            agencies_str = "; ".join(agencies)

            writer.writerow({
                "pmid": pmid,
                "title": title,
                "abstract": abstract,
                "authors": "; ".join(authors),
                "language": language,
                "year": year,
                "month": month,
                "publication_type": publication_type_str,
                "country": country,
                "agency": agencies_str,
                "mesh_terms": "; ".join(mesh_terms),
                "doi": doi
            })
            row_count += 1
# Out:
# Streaming PubMed:  13%|█▎        | 4379869/32500000 [1:23:02<3:41:13, 2118.51records/s]Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  30%|███       | 9899840/32500000 [3:06:46<2:23:37, 2622.46records/s]Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  42%|████▏     | 13529947/32500000 [4:18:00<2:03:32, 2559.31records/s]Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  52%|█████▏    | 16830000/32500000 [5:27:42<2:10:30, 2001.13records/s]Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  60%|█████▉    | 19428606/32500000 [6:33:00<2:05:30, 1735.80records/s]Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  68%|██████▊   | 22215511/32500000 [7:49:38<1:28:39, 1933.18records/s]Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  75%|███████▍  | 24291008/32500000 [8:54:34<1:12:27, 1888.05records/s]Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  75%|███████▍  | 24341905/32500000 [8:56:22<1:09:23, 1959.57records/s]Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  76%|███████▌  | 24748136/32500000 [9:08:52<1:12:54, 1772.00records/s]Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  80%|████████  | 26078086/32500000 [9:55:47<54:14, 1973.25records/s]  Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  81%|████████  | 26340000/32500000 [10:04:05<51:50, 1980.52records/s]  Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  86%|████████▌ | 27989895/32500000 [11:05:54<39:36, 1898.01records/s]  Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  87%|████████▋ | 28170000/32500000 [11:18:07<37:03, 1947.81records/s]  Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  88%|████████▊ | 28473210/32500000 [11:31:00<47:03, 1426.14records/s]  Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  89%|████████▊ | 28770950/32500000 [11:42:50<14:00:11, 73.97records/s] Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  90%|████████▉ | 29113622/32500000 [11:54:53<32:22, 1743.17records/s]  Ignoring field PublicationTypeList it's a <class 'str'> and we expect a <class 'dict'>
# Streaming PubMed:  90%|████████▉ | 29220000/32500000 [11:59:12<28:26, 1922.08records/s]  Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed:  91%|█████████ | 29490000/32500000 [12:09:30<25:03, 2002.15records/s]  Got disconnected from remote data host. Retrying in 5sec [1/20]
# Streaming PubMed: 36570000records [17:00:17, 597.38records/s]

# %%
output_file = "H:/Datasets/pubmed_full.csv"
fieldnames = [
    "pmid", "title", "abstract", "authors", "language", "year", "month",
    "publication_type", "country", "agency", "mesh_terms", "doi"
]

def get_first_doi(article_id_list):
    try:
        return article_id_list["ArticleId"][1][1]
    except:
        return ""

def get_year(example):
    try:
        return int(example["MedlineCitation"]["DateCompleted"]["Year"])
    except:
        return 0

stream = iter(dataset)
row_count = 0

with open(output_file, mode="w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

    with tqdm(total=32_500_000, desc="Streaming PubMed", unit="records") as pbar:
        while True:
            try:
                example = next(stream)
                pbar.update(1)
            except StopIteration:
                break
            except Exception:
                continue  # skip broken rows

            year = get_year(example)

            citation = example.get("MedlineCitation", {})
            article = citation.get("Article", {})
            pubmed_data = example.get("PubmedData", {})

            # Extract fields
            pmid = citation.get("PMID", "")
            title = article.get("ArticleTitle", "")
            abstract = article.get("Abstract", {}).get("AbstractText", "")
            language = article.get("Language", "")
            doi = get_first_doi(pubmed_data.get("ArticleIdList", {}))

            date_completed = citation.get("DateCompleted", {})
            month = date_completed.get("Month", "")

            authors_raw = article.get("AuthorList", {}).get("Author", {})
            last_names = authors_raw.get("LastName", [])
            fore_names = authors_raw.get("ForeName", [])
            authors = [f"{fn} {ln}" for fn, ln in zip(fore_names, last_names)]

            mesh = citation.get("MeshHeadingList", {}).get("MeshHeading", {})
            mesh_terms = mesh.get("DescriptorName", []) if isinstance(mesh, dict) else []

            publication_type = article.get("PublicationTypeList", {}).get("PublicationType", [])
            publication_type_str = "; ".join(publication_type)

            country = citation.get("MedlineJournalInfo", {}).get("Country", "")

            grant = article.get("GrantList", {}).get("Grant", {})
            agencies = grant.get("Agency", []) if isinstance(grant, dict) else []
            agencies_str = "; ".join(agencies)

            writer.writerow({
                "pmid": pmid,
                "title": title,
                "abstract": abstract,
                "authors": "; ".join(authors),
                "language": language,
                "year": year,
                "month": month,
                "publication_type": publication_type_str,
                "country": country,
                "agency": agencies_str,
                "mesh_terms": "; ".join(mesh_terms),
                "doi": doi
            })
            row_count += 1

# %% [markdown]
# ## Browsaing PubMed

# %%
df_t = pd.read_csv("Datasets/pubmed_since_2005.csv")

# %%
df_t
# Out:
#              pmid                                              title  \
# 0        10393939  Species richness and resource availability: a ...
# 1        11038575  Paul-Straubel-Kingdon trap for true zero-point...
# 2        11038577  The cloud-ionosphere discharge: a newly observ...
# 3        11038576  Implications of a possible clustering of highe...
# 4        11038578        Ordinary representations and modular forms.
# ...           ...                                                ...
# 1663747  38065126                    European Court of Human Rights.
# 1663748  38085332  Impact of the intra-aortic balloon pump on the...
# 1663749  38085330  SHP2 clinical phenotype, cancer, or RASopathie...
# 1663750  38085333  SMARCB1-deficient sinonasal adenocarcinoma: a ...
# 1663751  38085334  [Mastocytosis-a frequently unrecognized disease].
#
#                                                   abstract  \
# 0        The data on the number of species of insects a...
# 1        A modification of the Paul-Straubel trap previ...
# 2        This paper deals with a luminous electric disc...
# 3        Recently, a possible clustering of a subset of...
# 4                                                      NaN
# ...                                                    ...
# 1663747                                                NaN
# 1663748                                                NaN
# 1663749  SHP2 phosphatase promotes full activation of t...
# 1663750  SMARCB1-deficient sinonasal adenocarcinoma is ...
# 1663751  Mastocytosis is a rare disease characterized b...
#
#                                                    authors language  year  \
# 0                                 C K Kelly; T R Southwood      eng  2008
# 1                                          H Dehmelt; N Yu      eng  2008
# 2                                             J R Winckler      eng  2008
# 3                     G Sigl; D N Schramm; S Lee; C T Hill      eng  2008
# 4                                   C M Skinner; A J Wiles      eng  2008
# ...                                                    ...      ...   ...
# 1663747                            Joseph Dute; Tom Goffin      eng  2023
# 1663748  Nien-Hsun Wu; Tsung-Han Hsieh; Chun-Yu Chang; ...      eng  2024
# 1663749  Yonglan Liu; Wengang Zhang; Hyunbum Jang; Ruth...      eng  2023
# 1663750  Alena Skálová; Touraj Taheri; Martina Bradová;...      eng  2024
# 1663751                      Melba Muñoz; Frank Siebenhaar      ger  2024
#
#          month                   publication_type        country agency  \
# 0            4                    Journal Article  United States    NaN
# 1            4                    Journal Article  United States    NaN
# 2            4                    Journal Article  United States    NaN
# 3            4                    Journal Article  United States    NaN
# 4            4                    Journal Article  United States    NaN
# ...        ...                                ...            ...    ...
# 1663747     12      Case Reports; Journal Article    Netherlands    NaN
# 1663748      2                             Letter          Japan    NaN
# 1663749     12                    Journal Article    Switzerland    NaN
# 1663750      8                    Journal Article        Germany    NaN
# 1663751      1  English Abstract; Journal Article        Germany    NaN
#
#                                                 mesh_terms  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1663747                                                NaN
# 1663748  Humans; Coronary Artery Bypass, Off-Pump; Repr...
# 1663749  Humans; Protein Tyrosine Phosphatase, Non-Rece...
# 1663750  Humans; SMARCB1 Protein; Middle Aged; Male; Fe...
# 1663751  Child; Adult; Humans; Proto-Oncogene Proteins ...
#
#                                 doi
# 0                          PMC22179
# 1                             14192
# 2                             10848
# 3                             10846
# 4                             10849
# ...                             ...
# 1663747   10.1163/15718093-bja10116
# 1663748  10.1007/s00380-023-02347-5
# 1663749  10.1007/s00018-023-05052-8
# 1663750  10.1007/s00428-023-03650-2
# 1663751  10.1007/s00105-023-05258-8
#
# [1663752 rows x 12 columns]

# %% [markdown]
# ## Connecting to APIs
# ### PubMed

# %%
from Bio import Entrez
import time
import datetime
import pandas as pd

# %%
# Set email
Entrez.email = "perlinski.h@gmail.com"

# Calculate date range: last 30 days
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=30)
start_date_str = start_date.strftime("%Y/%m/%d")
end_date_str = end_date.strftime("%Y/%m/%d")

# Perform the search
handle = Entrez.esearch(
    db="pubmed",
    term="",
    datetype="pdat",
    mindate=start_date_str,
    maxdate=end_date_str,
    retmode="xml"
)
results = Entrez.read(handle)
handle.close()

# Output the count
print(f"Number of PubMed articles published from {start_date_str} to {end_date_str}: {results['Count']}")
# Out:
# Number of PubMed articles published from 2025/04/05 to 2025/05/05: 129749

# %% [markdown]
# 128k articles per month is a lot. The requrests through Entrez allow 10k max, which on some days is exceeded. An option is to download using pre-made day files.

# %%
import ftplib, requests, gzip, xml.etree.ElementTree as ET
import datetime, time, csv

# ── CONFIGURATION ─────────────────────────────────────────────────────────────
FTP_HOST   = "ftp.ncbi.nlm.nih.gov"
FTP_DIR    = "pubmed/updatefiles"
BASE_URL   = f"https://{FTP_HOST}/{FTP_DIR}/"
OUTPUT_CSV = "Datasets/pubmed_recent2.csv"

# Set your desired window here (inclusive; format YYYY-MM-DD)
START_DATE = "2025-04-25"
END_DATE   = "2025-05-05"

FIELDNAMES = [
    "pmid", "title", "abstract", "authors", "language",
    "pub_year", "pub_month",      # ← re-added month here
    "publication_type", "country",
    "agency", "mesh_terms", "doi"
]

# ── HELPER: iterate dates ─────────────────────────────────────────────────────
def daterange(start, end):
    days = (end - start).days + 1
    for i in range(days):
        yield start + datetime.timedelta(i)

# ── HELPER: list only .xml.gz for a date ───────────────────────────────────────
def list_xml_gz_for_date(day):
    ftp = ftplib.FTP(FTP_HOST)
    ftp.login()
    ftp.cwd(FTP_DIR)
    files = ftp.nlst()
    matched = []
    for fn in files:
        if not fn.endswith(".xml.gz"):
            continue
        try:
            ts = ftp.sendcmd(f"MDTM {fn}").split()[1]
            if datetime.datetime.strptime(ts, "%Y%m%d%H%M%S").date() == day:
                matched.append(fn)
        except:
            pass
    ftp.quit()
    return matched

# ── PARSE & FILTER ON YEAR ONLY ────────────────────────────────────────────────
def parse_updatefile(url, writer, start_year, end_year):
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with gzip.GzipFile(fileobj=r.raw) as gz:
            for _, elem in ET.iterparse(gz, events=("end",)):
                if elem.tag != "PubmedArticle":
                    continue

                mc = elem.find("MedlineCitation")
                ai = mc.find("Article") if mc is not None else None
                pd = elem.find("PubmedData")

                # Extract publication year & month
                pub_year = pub_month = None
                if ai is not None:
                    pdj = ai.find("Journal/JournalIssue/PubDate")
                    if pdj is not None:
                        y = pdj.findtext("Year","")
                        m = pdj.findtext("Month","")
                        if y and y.isdigit():
                            pub_year = int(y)
                        # Month may be numeric or abbrev
                        if m and m.isdigit():
                            pub_month = int(m)
                        else:
                            MONTH_MAP = {
                                "Jan":1,"Feb":2,"Mar":3,"Apr":4,
                                "May":5,"Jun":6,"Jul":7,"Aug":8,
                                "Sep":9,"Oct":10,"Nov":11,"Dec":12
                            }
                            pub_month = MONTH_MAP.get(m, None)

                # Filter on year only
                if pub_year is None or not (start_year <= pub_year <= end_year):
                    elem.clear()
                    continue

                # Extract other fields, including pub_month
                pmid  = mc.findtext("PMID","")
                title = ai.findtext("ArticleTitle","") if ai is not None else ""
                abstract = ""
                if ai is not None:
                    ab = ai.find("Abstract")
                    if ab is not None:
                        abstract = "".join(ab.itertext())
                authors = ""
                if ai is not None:
                    authors = "; ".join(
                        f"{a.findtext('ForeName','')} {a.findtext('LastName','')}"
                        for a in ai.findall("AuthorList/Author")
                    )
                language = ai.findtext("Language","") if ai is not None else ""
                mesh_terms = "; ".join(
                    mh.findtext("DescriptorName","")
                    for mh in mc.findall("MeshHeadingList/MeshHeading")
                ) if mc is not None else ""
                publication_type = "; ".join(
                    pt.text for pt in ai.findall("PublicationTypeList/PublicationType")
                ) if ai is not None else ""
                country = mc.findtext("MedlineJournalInfo/Country","")
                agency = "; ".join(
                    g.findtext("Agency","") for g in ai.findall("GrantList/Grant")
                ) if ai is not None else ""
                doi = ""
                if pd is not None:
                    for aid in pd.findall("ArticleIdList/ArticleId"):
                        if aid.get("IdType")=="doi" and aid.text:
                            doi = aid.text
                            break

                writer.writerow({
                    "pmid": pmid,
                    "title": title,
                    "abstract": abstract,
                    "authors": authors,
                    "language": language,
                    "pub_year": pub_year,
                    "pub_month": pub_month,    # ← and here
                    "publication_type": publication_type,
                    "country": country,
                    "agency": agency,
                    "mesh_terms": mesh_terms,
                    "doi": doi
                })

                elem.clear()

# ── MAIN EXECUTION ────────────────────────────────────────────────────────────
if __name__ == "__main__":
    start_dt = datetime.datetime.strptime(START_DATE, "%Y-%m-%d").date()
    end_dt   = datetime.datetime.strptime(END_DATE,   "%Y-%m-%d").date()
    start_year, end_year = start_dt.year, end_dt.year

    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as outf:
        writer = csv.DictWriter(outf, FIELDNAMES)
        writer.writeheader()

        for day in daterange(start_dt, end_dt):
            print(f"Processing {day}…")
            for fn in list_xml_gz_for_date(day):
                url = BASE_URL + fn
                print(f"  ↳ {fn}")
                try:
                    parse_updatefile(url, writer, start_year, end_year)
                except Exception as e:
                    print(f"    ! parse error: {e}")
                time.sleep(0.1)

    print(f"\n✅ Done – data with pub_month saved to {OUTPUT_CSV}")
# Out:
# Processing 2025-04-25…
#   ↳ pubmed25n1385.xml.gz
# Processing 2025-04-26…
#   ↳ pubmed25n1386.xml.gz
# Processing 2025-04-27…
# Processing 2025-04-28…
#   ↳ pubmed25n1387.xml.gz
#   ↳ pubmed25n1388.xml.gz
# Processing 2025-04-29…
#   ↳ pubmed25n1389.xml.gz
#   ↳ pubmed25n1390.xml.gz
# Processing 2025-04-30…
#   ↳ pubmed25n1391.xml.gz
# Processing 2025-05-01…
#   ↳ pubmed25n1392.xml.gz
# Processing 2025-05-02…
#   ↳ pubmed25n1393.xml.gz
# Processing 2025-05-03…
#   ↳ pubmed25n1394.xml.gz
# Processing 2025-05-04…
# Processing 2025-05-05…
#
# ✅ Done – data with pub_month saved to Datasets/pubmed_recent.csv

# %%
df = pd.read_csv("Datasets/pubmed_recent.csv")
df
# Out:
#             pmid                                              title  \
# 0       33534651  Reconstruction of elbow flexion after sarcoma ...
# 1       34590439  Association Between Rheumatoid Arthritis Disea...
# 2       34075844  Let us ask the patient: psychological well-bei...
# 3       35437059  The Effect of EDS-FLU on Objective and Patient...
# 4       35487204  Two cases of extraluminal migration of fishbon...
# ...          ...                                                ...
# 191674  40317095  Bridging acute and chronic stress effects on i...
# 191675  40317093  Activated alpha 9 integrin expression enables ...
# 191676  40317094  Redlining, reinvestment, and racial segregatio...
# 191677  40317097  Prevention of Heart Failure Induced by Doxorub...
# 191678  40317096  Nutritional and herbal interventions for polyc...
#
#                                                  abstract  \
# 0       \n          The latissimus dorsi flap is widel...
# 1       \n          To analyze the effect of tooth los...
# 2       \n          The onset of the COVID-19 pandemic...
# 3       \n          Exhalation delivery system with fl...
# 4       \n          Laryngopharyngeal or cervical pain...
# ...                                                   ...
# 191674  \n          Acute stress triggers adaptive phy...
# 191675  \n          Full recovery from spinal cord inj...
# 191676  \n          In the United States, firearm-rela...
# 191677  \n          Dexrazoxane, a putative iron chela...
# 191678  \n          Polycystic Ovary Syndrome (PCOS) i...
#
#                                                   authors language  pub_year  \
# 0       Matthieu Garcia; Yohan Legallois; Eberhard Sto...      eng      2025
# 1       Katinka Albrecht; Paola de Pablo; Thorsten Eid...      eng      2025
# 2       Ashley Welch; Jan Nijs; Ines Van Loo; Marina M...      eng      2025
# 3       Randall A Ow; John P McGinnis; Harry J Sacks; ...      eng      2025
# 4       Tae-Hun Lee; Sang-Wook Park; Somi Ryu; Ki Ju C...      eng      2025
# ...                                                   ...      ...       ...
# 191674  Lennart Seizer; Anja Pascher; Sonja Branz; Nad...      eng      2025
# 191675  Katerina Stepankova; Barbora Smejkalova; Lucia...      eng      2025
# 191676  Gia Barboza-Salerno; Brittany Liebhard; Sharef...      eng      2025
# 191677  Hui-Ming Chang; Jinn-Yuan Hsu; Chul Ahn; Edwar...      eng      2025
# 191678  Aya A Muhammed Saeed; Sobia Noreen; Farhang H ...      eng      2025
#
#         pub_month                              publication_type  \
# 0             4.0                 Journal Article; Case Reports
# 1             2.0          Journal Article; Observational Study
# 2             4.0                               Journal Article
# 3             2.0  Journal Article; Randomized Controlled Trial
# 4             2.0                 Journal Article; Case Reports
# ...           ...                                           ...
# 191674        5.0                               Journal Article
# 191675        5.0                               Journal Article
# 191676        5.0                               Journal Article
# 191677        5.0                               Journal Article
# 191678        5.0                       Journal Article; Review
#
#               country                                             agency  \
# 0             England                                                NaN
# 1       United States  Deutsche Rheuma-Liga Bundesverband e.V.; Pfize...
# 2             England                                                NaN
# 3       United States                                                NaN
# 4       United States                                                NaN
# ...               ...                                                ...
# 191674        England                                                NaN
# 191675        England  Grantová Agentura, Univerzita Karlova; Grantov...
# 191676        England                                                NaN
# 191677        England                 NIH HHS; NIH HHS; NIH HHS; NIH HHS
# 191678     Bangladesh                                                NaN
#
#                                                mesh_terms  \
# 0       Humans; Surgical Flaps; Sarcoma; Superficial B...
# 1       Humans; Arthritis, Rheumatoid; Male; Tooth Los...
# 2       Humans; COVID-19; Male; Female; Cardiac Surgic...
# 3       Humans; Sinusitis; Nasal Polyps; Rhinitis; Chr...
# 4       Animals; Female; Humans; Middle Aged; Fishes; ...
# ...                                                   ...
# 191674  Humans; Longitudinal Studies; Stress, Psycholo...
# 191675  Animals; Spinal Cord Injuries; Nerve Regenerat...
# 191676                                                NaN
# 191677                                                NaN
# 191678  Humans; Polycystic Ovary Syndrome; Female; Die...
#
#                                   doi
# 0       10.1080/00015458.2021.1883392
# 1                   10.1002/acr.24799
# 2       10.1080/00015458.2021.1917749
# 3           10.1177/01455613221088698
# 4           10.1177/01455613221098787
# ...                               ...
# 191674     10.1186/s40359-025-02777-y
# 191675     10.1186/s40478-025-01995-0
# 191676     10.1186/s40621-025-00579-9
# 191677     10.1186/s40959-025-00339-0
# 191678     10.1186/s41043-025-00899-y
#
# [191679 rows x 12 columns]

# %% [markdown]
# ### Crossref

# %%
#!/usr/bin/env python3
import requests, csv, time, datetime

# ── CONFIG ─────────────────────────────────────────────────────────────────────
START_DATE = "2025-04-05"   # inclusive
END_DATE   = "2025-05-05"   # inclusive
OUTPUT_CSV = "Datasets/crossref_last_month2.csv"

# Fields to extract
FIELDNAMES = [
    "doi", "title", "abstract", "authors", "language",
    "pub_year", "pub_month", "type", "publisher",
    "funders", "subjects", "url"
]

# Base API endpoint
API_URL = "https://api.crossref.org/works"
# Build the date filter
date_filter = f"from-pub-date:{START_DATE},until-pub-date:{END_DATE}"

# ── 1) Get the total count of matching works -------------------------------
# rows=0 returns no items but populates message["total-results"]
resp = requests.get(API_URL, params={
    "filter": date_filter,
    "rows": 0
})
resp.raise_for_status()
message = resp.json()["message"]
total = message["total-results"]    # approximate total count :contentReference[oaicite:3]{index=3}
print(f"Total works in period: {total}")

# ── 2) Page through all records with cursor pagination ----------------------
cursor = "*"    # initial cursor for deep paging :contentReference[oaicite:4]{index=4}
rows   = 1000   # max items per batch

with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, FIELDNAMES)
    writer.writeheader()
    fetched = 0

    while fetched < total:
        params = {
            "filter": date_filter,
            "rows": rows,
            "cursor": cursor,
        }
        r = requests.get(API_URL, params=params)
        r.raise_for_status()
        msg = r.json()["message"]

        items = msg.get("items", [])
        if not items:
            break  # no more data

        # Extract and write each item
        for item in items:
            doi = item.get("DOI", "")
            title = " ".join(item.get("title", []))
            abstract = item.get("abstract", "").replace("<jats:p>","").replace("</jats:p>","")
            authors = "; ".join(
                f"{a.get('given','')} {a.get('family','')}"
                for a in item.get("author", [])
                if a.get("given") and a.get("family")
            )
            language = item.get("language", "")
            issued = item.get("issued", {}).get("date-parts", [])
            pub_year = issued[0][0] if issued and issued[0] else ""
            pub_month = issued[0][1] if issued and len(issued[0]) > 1 else ""
            typ = item.get("type", "")
            publisher = item.get("publisher", "")
            funders = "; ".join(f.get("name","") for f in item.get("funder", []))
            subjects = "; ".join(item.get("subject", []))
            url = item.get("URL", "")

            writer.writerow({
                "doi": doi, "title": title, "abstract": abstract,
                "authors": authors, "language": language,
                "pub_year": pub_year, "pub_month": pub_month,
                "type": typ, "publisher": publisher,
                "funders": funders, "subjects": subjects, "url": url
            })

        fetched += len(items)
        print(f"Fetched {fetched}/{total} works…")

        # Prepare next cursor
        next_cursor = msg.get("next-cursor")
        if not next_cursor:
            break
        cursor = next_cursor  # update for next loop

        time.sleep(0.4)  # polite pacing: ~1 request/sec :contentReference[oaicite:5]{index=5}

print(f"\n✅ Done! Retrieved {fetched} works into {OUTPUT_CSV}")
# Out:
# Total works in period: 418221
# Fetched 1000/418221 works…
# Fetched 2000/418221 works…
# Fetched 3000/418221 works…
# Fetched 4000/418221 works…
# Fetched 5000/418221 works…
# Fetched 6000/418221 works…
# Fetched 7000/418221 works…
# Fetched 8000/418221 works…
# Fetched 9000/418221 works…
# Fetched 10000/418221 works…
# Fetched 11000/418221 works…
# Fetched 12000/418221 works…
# Fetched 13000/418221 works…
# Fetched 14000/418221 works…
# Fetched 15000/418221 works…
# Fetched 16000/418221 works…
# Fetched 17000/418221 works…
# Fetched 18000/418221 works…
# Fetched 19000/418221 works…
# Fetched 20000/418221 works…
# Fetched 21000/418221 works…
# Fetched 22000/418221 works…
# Fetched 23000/418221 works…
# Fetched 24000/418221 works…
# Fetched 25000/418221 works…
# Fetched 26000/418221 works…
# Fetched 27000/418221 works…
# Fetched 28000/418221 works…
# Fetched 29000/418221 works…
# Fetched 30000/418221 works…
# Fetched 31000/418221 works…
# Fetched 32000/418221 works…
# Fetched 33000/418221 works…
# Fetched 34000/418221 works…
# Fetched 35000/418221 works…
# Fetched 36000/418221 works…
# Fetched 37000/418221 works…
# Fetched 38000/418221 works…
# Fetched 39000/418221 works…
# Fetched 40000/418221 works…
# Fetched 41000/418221 works…
# Fetched 42000/418221 works…
# Fetched 43000/418221 works…
# Fetched 44000/418221 works…
# Fetched 45000/418221 works…
# Fetched 46000/418221 works…
# Fetched 47000/418221 works…
# Fetched 48000/418221 works…
# Fetched 49000/418221 works…
# Fetched 50000/418221 works…
# Fetched 51000/418221 works…
# Fetched 52000/418221 works…
# Fetched 53000/418221 works…
# Fetched 54000/418221 works…
# Fetched 55000/418221 works…
# Fetched 56000/418221 works…
# Fetched 57000/418221 works…
# Fetched 58000/418221 works…
# Fetched 59000/418221 works…
# Fetched 60000/418221 works…
# Fetched 61000/418221 works…
# Fetched 62000/418221 works…
# Fetched 63000/418221 works…
# Fetched 64000/418221 works…
# Fetched 65000/418221 works…
# Fetched 66000/418221 works…
# Fetched 67000/418221 works…
# Fetched 68000/418221 works…
# Fetched 69000/418221 works…
# Fetched 70000/418221 works…
# Fetched 71000/418221 works…
# Fetched 72000/418221 works…
# Fetched 73000/418221 works…
# Fetched 74000/418221 works…
# Fetched 75000/418221 works…
# Fetched 76000/418221 works…
# Fetched 77000/418221 works…
# Fetched 78000/418221 works…
# Fetched 79000/418221 works…
# Fetched 80000/418221 works…
# Fetched 81000/418221 works…
# Fetched 82000/418221 works…
# Fetched 83000/418221 works…
# Fetched 84000/418221 works…
# Fetched 85000/418221 works…
# Fetched 86000/418221 works…
# Fetched 87000/418221 works…
# Fetched 88000/418221 works…
# Fetched 89000/418221 works…
# Fetched 90000/418221 works…
# Fetched 91000/418221 works…
# Fetched 92000/418221 works…
# Fetched 93000/418221 works…
# Fetched 94000/418221 works…
# Fetched 95000/418221 works…
# Fetched 96000/418221 works…
# Fetched 97000/418221 works…
# Fetched 98000/418221 works…
# Fetched 99000/418221 works…
# Fetched 100000/418221 works…
# Fetched 101000/418221 works…
# Fetched 102000/418221 works…
# Fetched 103000/418221 works…
# Fetched 104000/418221 works…
# Fetched 105000/418221 works…
# Fetched 106000/418221 works…
# Fetched 107000/418221 works…
# Fetched 108000/418221 works…
# Fetched 109000/418221 works…
# Fetched 110000/418221 works…
# Fetched 111000/418221 works…
# Fetched 112000/418221 works…
# Fetched 113000/418221 works…
# Fetched 114000/418221 works…
# Fetched 115000/418221 works…
# Fetched 116000/418221 works…
# Fetched 117000/418221 works…
# Fetched 118000/418221 works…
# Fetched 119000/418221 works…
# Fetched 120000/418221 works…
# Fetched 121000/418221 works…
# Fetched 122000/418221 works…
# Fetched 123000/418221 works…
# Fetched 124000/418221 works…
# Fetched 125000/418221 works…
# Fetched 126000/418221 works…
# Fetched 127000/418221 works…
# Fetched 128000/418221 works…
# Fetched 129000/418221 works…
# Fetched 130000/418221 works…
# Fetched 131000/418221 works…
# Fetched 132000/418221 works…
# Fetched 133000/418221 works…
# Fetched 134000/418221 works…
# Fetched 135000/418221 works…
# Fetched 136000/418221 works…
# Fetched 137000/418221 works…
# Fetched 138000/418221 works…
# Fetched 139000/418221 works…
# Fetched 140000/418221 works…
# Fetched 141000/418221 works…
# Fetched 142000/418221 works…
# Fetched 143000/418221 works…
# Fetched 144000/418221 works…
# Fetched 145000/418221 works…
# Fetched 146000/418221 works…
# Fetched 147000/418221 works…
# Fetched 148000/418221 works…
# Fetched 149000/418221 works…
# Fetched 150000/418221 works…
# Fetched 151000/418221 works…
# Fetched 152000/418221 works…
# Fetched 153000/418221 works…
# Fetched 154000/418221 works…
# Fetched 155000/418221 works…
# Fetched 156000/418221 works…
# Fetched 157000/418221 works…
# Fetched 158000/418221 works…
# Fetched 159000/418221 works…
# Fetched 160000/418221 works…
# Fetched 161000/418221 works…
# Fetched 162000/418221 works…
# Fetched 163000/418221 works…
# Fetched 164000/418221 works…
# Fetched 165000/418221 works…
# Fetched 166000/418221 works…
# Fetched 167000/418221 works…
# Fetched 168000/418221 works…
# Fetched 169000/418221 works…
# Fetched 170000/418221 works…
# Fetched 171000/418221 works…
# Fetched 172000/418221 works…
# Fetched 173000/418221 works…
# Fetched 174000/418221 works…
# Fetched 175000/418221 works…
# Fetched 176000/418221 works…
# Fetched 177000/418221 works…
# Fetched 178000/418221 works…
# Fetched 179000/418221 works…
# Fetched 180000/418221 works…
# Fetched 181000/418221 works…
# Fetched 182000/418221 works…
# Fetched 183000/418221 works…
# Fetched 184000/418221 works…
# Fetched 185000/418221 works…
# Fetched 186000/418221 works…
# Fetched 187000/418221 works…
# Fetched 188000/418221 works…
# Fetched 189000/418221 works…
# Fetched 190000/418221 works…
# Fetched 191000/418221 works…
# Fetched 192000/418221 works…
# Fetched 193000/418221 works…
# Fetched 194000/418221 works…
# Fetched 195000/418221 works…
# Fetched 196000/418221 works…
# Fetched 197000/418221 works…
# Fetched 198000/418221 works…
# Fetched 199000/418221 works…
# Fetched 200000/418221 works…
# Fetched 201000/418221 works…
# Fetched 202000/418221 works…
# Fetched 203000/418221 works…
# Fetched 204000/418221 works…
# Fetched 205000/418221 works…
# Fetched 206000/418221 works…
# Fetched 207000/418221 works…
# Fetched 208000/418221 works…
# Fetched 209000/418221 works…
# Fetched 210000/418221 works…
# Fetched 211000/418221 works…
# Fetched 212000/418221 works…
# Fetched 213000/418221 works…
# Fetched 214000/418221 works…
# Fetched 215000/418221 works…
# Fetched 216000/418221 works…
# Fetched 217000/418221 works…
# Fetched 218000/418221 works…
# Fetched 219000/418221 works…
# Fetched 220000/418221 works…
# Fetched 221000/418221 works…
# Fetched 222000/418221 works…
# Fetched 223000/418221 works…
# Fetched 224000/418221 works…
# Fetched 225000/418221 works…
# Fetched 226000/418221 works…
# Fetched 227000/418221 works…
# Fetched 228000/418221 works…
# Fetched 229000/418221 works…
# Fetched 230000/418221 works…
# Fetched 231000/418221 works…
# Fetched 232000/418221 works…
# Fetched 233000/418221 works…
# Fetched 234000/418221 works…
# Fetched 235000/418221 works…
# Fetched 236000/418221 works…
# Fetched 237000/418221 works…
# Fetched 238000/418221 works…
# Fetched 239000/418221 works…
# Fetched 240000/418221 works…
# Fetched 241000/418221 works…
# Fetched 242000/418221 works…
# Fetched 243000/418221 works…
# Fetched 244000/418221 works…
# Fetched 245000/418221 works…
# Fetched 246000/418221 works…
# Fetched 247000/418221 works…
# Fetched 248000/418221 works…
# Fetched 249000/418221 works…
# Fetched 250000/418221 works…
# Fetched 251000/418221 works…
# Fetched 252000/418221 works…
# Fetched 253000/418221 works…
# Fetched 254000/418221 works…
# Fetched 255000/418221 works…
# Fetched 256000/418221 works…
# Fetched 257000/418221 works…
# Fetched 258000/418221 works…
# Fetched 259000/418221 works…
# Fetched 260000/418221 works…
# Fetched 261000/418221 works…
# Fetched 262000/418221 works…
# Fetched 263000/418221 works…
# Fetched 264000/418221 works…
# Fetched 265000/418221 works…
# Fetched 266000/418221 works…
# Fetched 267000/418221 works…
# Fetched 268000/418221 works…
# Fetched 269000/418221 works…
# Fetched 270000/418221 works…
# Fetched 271000/418221 works…
# Fetched 272000/418221 works…
# Fetched 273000/418221 works…
# Fetched 274000/418221 works…
# Fetched 275000/418221 works…
# Fetched 276000/418221 works…
# Fetched 277000/418221 works…
# Fetched 278000/418221 works…
# Fetched 279000/418221 works…
# Fetched 280000/418221 works…
# Fetched 281000/418221 works…
# Fetched 282000/418221 works…
# Fetched 283000/418221 works…
# Fetched 284000/418221 works…
# Fetched 285000/418221 works…
# Fetched 286000/418221 works…
# Fetched 287000/418221 works…
# Fetched 288000/418221 works…
# Fetched 289000/418221 works…
# Fetched 290000/418221 works…
# Fetched 291000/418221 works…
# Fetched 292000/418221 works…
# Fetched 293000/418221 works…
# Fetched 294000/418221 works…
# Fetched 295000/418221 works…
# Fetched 296000/418221 works…
# Fetched 297000/418221 works…
# Fetched 298000/418221 works…
# Fetched 299000/418221 works…
# Fetched 300000/418221 works…
# Fetched 301000/418221 works…
# Fetched 302000/418221 works…
# Fetched 303000/418221 works…
# Fetched 304000/418221 works…
# Fetched 305000/418221 works…
# Fetched 306000/418221 works…
# Fetched 307000/418221 works…
# Fetched 308000/418221 works…
# Fetched 309000/418221 works…
# Fetched 310000/418221 works…
# Fetched 311000/418221 works…
# Fetched 312000/418221 works…
# Fetched 313000/418221 works…
# Fetched 314000/418221 works…
# Fetched 315000/418221 works…
# Fetched 316000/418221 works…
# Fetched 317000/418221 works…
# Fetched 318000/418221 works…
# Fetched 319000/418221 works…
# Fetched 320000/418221 works…
# Fetched 321000/418221 works…
# Fetched 322000/418221 works…
# Fetched 323000/418221 works…
# Fetched 324000/418221 works…
# Fetched 325000/418221 works…
# Fetched 326000/418221 works…
# Fetched 327000/418221 works…
# Fetched 328000/418221 works…
# Fetched 329000/418221 works…
# Fetched 330000/418221 works…
# Fetched 331000/418221 works…
# Fetched 332000/418221 works…
# Fetched 333000/418221 works…
# Fetched 334000/418221 works…
# Fetched 335000/418221 works…
# Fetched 336000/418221 works…
# Fetched 337000/418221 works…
# Fetched 338000/418221 works…
# Fetched 339000/418221 works…
# Fetched 340000/418221 works…
# Fetched 341000/418221 works…
# Fetched 342000/418221 works…
# Fetched 343000/418221 works…
# Fetched 344000/418221 works…
# Fetched 345000/418221 works…
# Fetched 346000/418221 works…
# Fetched 347000/418221 works…
# Fetched 348000/418221 works…
# Fetched 349000/418221 works…
# Fetched 350000/418221 works…
# Fetched 351000/418221 works…
# Fetched 352000/418221 works…
# Fetched 353000/418221 works…
# Fetched 354000/418221 works…
# Fetched 355000/418221 works…
# Fetched 356000/418221 works…
# Fetched 357000/418221 works…
# Fetched 358000/418221 works…
# Fetched 359000/418221 works…
# Fetched 360000/418221 works…
# Fetched 361000/418221 works…
# Fetched 362000/418221 works…
# Fetched 363000/418221 works…
# Fetched 364000/418221 works…
# Fetched 365000/418221 works…
# Fetched 366000/418221 works…
# Fetched 367000/418221 works…
# Fetched 368000/418221 works…
# Fetched 369000/418221 works…
# Fetched 370000/418221 works…
# Fetched 371000/418221 works…
# Fetched 372000/418221 works…
# Fetched 373000/418221 works…
# Fetched 374000/418221 works…
# Fetched 375000/418221 works…
# Fetched 376000/418221 works…
# Fetched 377000/418221 works…
# Fetched 378000/418221 works…
# Fetched 379000/418221 works…
# Fetched 380000/418221 works…
# Fetched 381000/418221 works…
# Fetched 382000/418221 works…
# Fetched 383000/418221 works…
# Fetched 384000/418221 works…
# Fetched 385000/418221 works…
# Fetched 386000/418221 works…
# Fetched 387000/418221 works…
# Fetched 388000/418221 works…
# Fetched 389000/418221 works…
# Fetched 390000/418221 works…
# Fetched 391000/418221 works…
# Fetched 392000/418221 works…
# Fetched 393000/418221 works…
# Fetched 394000/418221 works…
# Fetched 395000/418221 works…
# Fetched 396000/418221 works…
# Fetched 397000/418221 works…
# Fetched 398000/418221 works…
# Fetched 399000/418221 works…
# Fetched 400000/418221 works…
# Fetched 401000/418221 works…
# Fetched 402000/418221 works…
# Fetched 403000/418221 works…
# Fetched 404000/418221 works…
# Fetched 405000/418221 works…
# Fetched 406000/418221 works…
# Fetched 407000/418221 works…
# Fetched 408000/418221 works…
# Fetched 409000/418221 works…
# Fetched 410000/418221 works…
# Fetched 411000/418221 works…
# Fetched 412000/418221 works…
# Fetched 413000/418221 works…
# Fetched 414000/418221 works…
# Fetched 415000/418221 works…
# Fetched 416000/418221 works…
# Fetched 417000/418221 works…
# Fetched 418000/418221 works…
# Fetched 418221/418221 works…
#
# ✅ Done! Retrieved 418221 works into Datasets/crossref_last_month.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("Datasets/crossref_last_month.csv")
df
# Out:
#                                        doi  \
# 0       10.1093/oso/9780197743720.003.0008
# 1           10.1016/j.ijbiomac.2025.141672
# 2          10.1016/j.fusengdes.2025.114900
# 3            10.1016/j.solener.2025.113344
# 4            10.1016/j.solener.2025.113381
# ...                                    ...
# 418216          10.1016/j.ajog.2025.04.062
# 418217          10.4103/jiaps.jiaps_292_24
# 418218        10.1021/acs.macromol.4c03231
# 418219         10.21511/imfi.22(2).2025.09
# 418220        10.1016/j.envdev.2025.101230
#
#                                                     title  \
# 0                 What Should Enforcement Do, and Not Do?
# 1       Magnesium-gallate MOF integrated conductive cr...
# 2       Steady-state Superconducting Advanced Spherica...
# 3       Deriving the orientation of existing solar ene...
# 4       Cyclostationary analysis for fault detection i...
# ...                                                   ...
# 418216  Robotic-assisted surgery for endometrial cance...
# 418217  Urinary Bladder/ Posterior Urethra Morphology ...
# 418218  Phase Behavior and Thermal Properties of Preci...
# 418219  The moderating role of investor sentiment on p...
# 418220  Assessing land use dynamics and their ecologic...
#
#                                                  abstract  \
# 0       <jats:title>Abstract</jats:title>\n           ...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 418216                                                NaN
# 418217                                                NaN
# 418218                                                NaN
# 418219  Common market anomalies tested in developed ma...
# 418220                                                NaN
#
#                                                   authors language  pub_year  \
# 0                                        Hiroshi Motomura       en      2025
# 1       Guangyu Li; Yue Wang; Yanyun Pang; Xinyu Wang;...       en      2025
# 2                         Yoshio Nagayama; Takaaki Fujita       en      2025
# 3         David Lingfors; Robert Johansson; Johan Lindahl       en      2025
# 4                   Mohammed Telidjane; Benaoumeur Bakhti       en      2025
# ...                                                   ...      ...       ...
# 418216     Elina KIVEKÄS; Synnöve STAFF; Minna M. MÄENPÄÄ       en      2025
# 418217                                        Ramesh Babu       en      2025
# 418218  Michael Patrick Blatt; Cecilia Hansen; Victori...       en      2025
# 418219  Zaida Rizqi Zainul; Khaira Amalia Fachrudin; N...      NaN      2025
# 418220  Jihwan Kim; Gawoo Kim; Youngkeun Song; Toshino...       en      2025
#
#         pub_month             type                                  publisher  \
# 0               4     book-chapter            Oxford University PressNew York
# 1               5  journal-article                                Elsevier BV
# 2               5  journal-article                                Elsevier BV
# 3               5  journal-article                                Elsevier BV
# 4               5  journal-article                                Elsevier BV
# ...           ...              ...                                        ...
# 418216          5  journal-article                                Elsevier BV
# 418217          4  journal-article  Ovid Technologies (Wolters Kluwer Health)
# 418218          5  journal-article            American Chemical Society (ACS)
# 418219          4  journal-article              LLC CPC Business Perspectives
# 418220          5  journal-article                                Elsevier BV
#
#                                                   funders  subjects  \
# 0                                                     NaN       NaN
# 1       Sinopec Ministry of Science and Technology Bas...       NaN
# 2       Nagoya Institute of Technology; National Insti...       NaN
# 3               STandUP for Energy; Swedish Energy Agency       NaN
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 418216                                                NaN       NaN
# 418217                                                NaN       NaN
# 418218  Vehicle Technologies Office; National Science ...       NaN
# 418219                                                NaN       NaN
# 418220                             Japan Prize Foundation       NaN
#
#                                                       url
# 0       https://doi.org/10.1093/oso/9780197743720.003....
# 1          https://doi.org/10.1016/j.ijbiomac.2025.141672
# 2         https://doi.org/10.1016/j.fusengdes.2025.114900
# 3           https://doi.org/10.1016/j.solener.2025.113344
# 4           https://doi.org/10.1016/j.solener.2025.113381
# ...                                                   ...
# 418216         https://doi.org/10.1016/j.ajog.2025.04.062
# 418217         https://doi.org/10.4103/jiaps.jiaps_292_24
# 418218       https://doi.org/10.1021/acs.macromol.4c03231
# 418219        https://doi.org/10.21511/imfi.22(2).2025.09
# 418220       https://doi.org/10.1016/j.envdev.2025.101230
#
# [418221 rows x 12 columns]

# %% [markdown]
# ### arXiv

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import time, csv, datetime
import xml.etree.ElementTree as ET
from tqdm import tqdm

# ── USER CONFIGURATION ─────────────────────────────────────────────────────────
START_DATE   = "2025-04-25"   # inclusive, YYYY-MM-DD
END_DATE     = "2025-05-05"   # inclusive
OUTPUT_CSV   = "Datasets/arxiv_recent2.csv"

FIELDNAMES = [
    "arxiv_id", "title", "abstract", "authors",
    "pub_year", "pub_month", "doi",
    "primary_category", "categories", "pdf_url"
]

# OAI-PMH endpoint & metadata format
OAI_URL       = "http://export.arxiv.org/oai2"
METADATA_PREF = "arXiv"          
PAUSE_SECONDS = 5

# parse ISO date
def iso_to_date(s):
    return datetime.datetime.strptime(s, "%Y-%m-%d").date()

start_dt = iso_to_date(START_DATE)
end_dt   = iso_to_date(END_DATE)

# XML namespaces
ns = {
    "oai":   "http://www.openarchives.org/OAI/2.0/",
    "arxiv": "http://arxiv.org/OAI/arXiv/"
}

session = requests.Session()
retries = Retry(total=5, backoff_factor=1,
                status_forcelist=[500,502,503,504])
session.mount("http://", HTTPAdapter(max_retries=retries))

# OPEN OUTPUT CSV 
with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as csvf:
    writer = csv.DictWriter(csvf, FIELDNAMES, quoting=csv.QUOTE_MINIMAL)
    writer.writeheader()

    resumption_token = None
    fetched = 0
    pbar = None

    while True:
        # build params
        if resumption_token:
            params = {
                "verb":            "ListRecords",
                "resumptionToken": resumption_token
            }
        else:
            params = {
                "verb":           "ListRecords",
                "metadataPrefix": METADATA_PREF,
                "from":           START_DATE,
                "until":          END_DATE
            }

        resp = session.get(OAI_URL, params=params)
        resp.raise_for_status()
        root = ET.fromstring(resp.text)

        # initialize progress bar once we know the total size
        if not pbar:
            token_el = root.find(".//oai:resumptionToken", ns)
            if token_el is not None:
                size = token_el.attrib.get("completeListSize")
                if size and size.isdigit():
                    pbar = tqdm(total=int(size), desc="records", unit="rec")
            if not pbar:
                pbar = tqdm(desc="records", unit="rec")

        for rec in root.findall(".//oai:record", ns):
            md = rec.find("oai:metadata/arxiv:arXiv", ns)
            if md is None:
                continue  # skip deletions or empty

            # true submission date
            created = md.findtext("arxiv:created", namespaces=ns)
            if not created:
                continue
            cdate = datetime.datetime.strptime(created, "%Y-%m-%d").date()
            if cdate < start_dt or cdate > end_dt:
                continue

            # extract fields
            aid    = md.findtext("arxiv:id",       namespaces=ns).strip()
            title  = md.findtext("arxiv:title",    namespaces=ns).strip()
            abstr  = md.findtext("arxiv:abstract", namespaces=ns).strip()

            # build full author names
            authors = []
            for a in md.findall("arxiv:authors/arxiv:author", ns):
                fore = a.findtext("arxiv:forenames", namespaces=ns) or ""
                key  = a.findtext("arxiv:keyname",   namespaces=ns) or ""
                full = " ".join(p for p in (fore, key) if p)
                if full:
                    authors.append(full)
            authors = "; ".join(authors)

            py, pm = cdate.year, cdate.month
            doi = md.findtext("arxiv:doi", namespaces=ns) or ""

            # categories is its own element
            cat_text   = md.findtext("arxiv:categories", namespaces=ns) or ""
            categories = cat_text.split()
            primary    = categories[0] if categories else ""

            pdf_url = f"http://arxiv.org/pdf/{aid}.pdf"

            writer.writerow({
                "arxiv_id":         aid,
                "title":            title,
                "abstract":         abstr,
                "authors":          authors,
                "pub_year":         py,
                "pub_month":        pm,
                "doi":              doi,
                "primary_category": primary,
                "categories":       "; ".join(categories),
                "pdf_url":          pdf_url
            })
            fetched += 1
            pbar.update(1)

        # handle resumptionToken
        token_el = root.find(".//oai:resumptionToken", ns)
        if token_el is None or not token_el.text:
            break
        resumption_token = token_el.text
        time.sleep(PAUSE_SECONDS)

    if pbar:
        pbar.close()

print(f"\n✅ Done – harvested {fetched} new arXiv records into {OUTPUT_CSV}")
# Out:
# records:  45%|████▍     | 5049/11315 [02:27<03:02, 34.25rec/s]
# ✅ Done – harvested 5049 new arXiv records into Datasets/arxiv_recent2.csv

# %%
df = pd.read_csv("Datasets/arxiv_recent.csv")
df
# Out:
#         arxiv_id                                              title  \
# 0     2504.18055  Why Does My Transaction Fail? A First Look at ...
# 1     2504.18056  Range-based 6-DoF Monte Carlo SLAM with Gradie...
# 2     2504.18057  Opportunistic Collaborative Planning with Larg...
# 3     2504.18058  Exploring Personality-Aware Interactions in Sa...
# 4     2504.18059  POET: Prompt Offset Tuning for Continual Human...
# ...          ...                                                ...
# 5044  2505.01421        Galaxy Zoo CEERS: Bar fractions up to z~4.0
# 5045  2505.01422  Neutrino mass generation in asymptotically saf...
# 5046  2505.01423  Negative Stepsizes Make Gradient-Descent-Ascen...
# 5047  2505.01424  Computational, Data-Driven, and Physics-Inform...
# 5048  2505.01425         GENMO: A GENeralist Model for Human MOtion
#
#                                                abstract  \
# 0     Solana is an emerging blockchain platform, rec...
# 1     This paper presents range-based 6-DoF Monte Ca...
# 2     Navigating autonomous vehicles in open scenari...
# 3     The integration of dialogue agents into the sa...
# 4     As extended reality (XR) is redefining how use...
# ...                                                 ...
# 5044  We study the evolution of the bar fraction in ...
# 5045  There exist several distinct phenomenological ...
# 5046  Efficient computation of min-max problems is a...
# 5047  Metal additive manufacturing enables unprecede...
# 5048  Human motion modeling traditionally separates ...
#
#                                                 authors  pub_year  pub_month  \
# 0     Xiaoye Zheng; Zhiyuan Wan; David Lo; Difan Xie...      2025          4
# 1     Takumi Nakao; Kenji Koide; Aoki Takanose; Shuj...      2025          4
# 2     Jiayi Chen; Shuai Wang; Guoliang Li; Wei Xu; G...      2025          4
# 3              Sijia Cheng; Wen-Yu Chang; Yun-Nung Chen      2025          4
# 4     Prachi Garg; Joseph K J; Vineeth N Balasubrama...      2025          4
# ...                                                 ...       ...        ...
# 5044  Tobias Géron; R. J. Smethurst; Hugh Dickinson;...      2025          5
# 5045  Gustavo P. de Brito; Astrid Eichhorn; Antonio ...      2025          5
# 5046                 Henry Shugart; Jason M. Altschuler      2025          5
# 5047                     D. Patel; R. Sharma; Y. B. Guo      2025          5
# 5048  Jiefeng Li; Jinkun Cao; Haotian Zhang; Davis R...      2025          5
#
#                                doi primary_category  \
# 0                  10.1145/3728943            cs.SE
# 1                              NaN            cs.RO
# 2                              NaN            cs.RO
# 3                              NaN            cs.CL
# 4     10.1007/978-3-031-73039-9_25            cs.CV
# ...                            ...              ...
# 5044                           NaN      astro-ph.GA
# 5045                           NaN           hep-ph
# 5046                           NaN          math.OC
# 5047                           NaN            cs.LG
# 5048                           NaN            cs.GR
#
#                              categories                              pdf_url
# 0                                 cs.SE  http://arxiv.org/pdf/2504.18055.pdf
# 1                                 cs.RO  http://arxiv.org/pdf/2504.18056.pdf
# 2                          cs.RO; cs.AI  http://arxiv.org/pdf/2504.18057.pdf
# 3                          cs.CL; cs.AI  http://arxiv.org/pdf/2504.18058.pdf
# 4                                 cs.CV  http://arxiv.org/pdf/2504.18059.pdf
# ...                                 ...                                  ...
# 5044                        astro-ph.GA  http://arxiv.org/pdf/2505.01421.pdf
# 5045              hep-ph; gr-qc; hep-th  http://arxiv.org/pdf/2505.01422.pdf
# 5046              math.OC; cs.DS; cs.LG  http://arxiv.org/pdf/2505.01423.pdf
# 5047                              cs.LG  http://arxiv.org/pdf/2505.01424.pdf
# 5048  cs.GR; cs.AI; cs.CV; cs.LG; cs.RO  http://arxiv.org/pdf/2505.01425.pdf
#
# [5049 rows x 10 columns]
