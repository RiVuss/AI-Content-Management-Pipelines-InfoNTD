# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ast
import re
from wordcloud import WordCloud

# %% [markdown]
# # Trends in InfoNTD/Infolep data
# ### Data load

# %%
df_ntd = pd.read_csv('Datasets/publicationsDatasetInfoPortals.csv')
df_ntd
# Out:
#        Unnamed: 0    bib_id     bibcite_type  \
# 0               0       6.0           thesis
# 1               1      34.0  journal_article
# 2               2      35.0  journal_article
# 3               3      36.0  journal_article
# 4               4      37.0  journal_article
# ...           ...       ...              ...
# 42358       42358  102107.0  journal_article
# 42359       42359  102108.0  journal_article
# 42360       42360  102109.0  journal_article
# 42361       42361  102110.0  journal_article
# 42362       42362  102111.0           report
#
#                                        uuid  \
# 0      a8d83e03-2a58-4fce-9110-5d57b35c348a
# 1      734c3399-ba63-45b9-ac23-f48282a58733
# 2      55b5e61a-ffd7-4fb6-974b-e0aab3ee65d9
# 3      7ca86ad1-bfb7-4201-8873-3b07edb8a1a6
# 4      e392dec7-01bc-49d7-a496-5916a29aef48
# ...                                     ...
# 42358  d84c760e-547d-4d52-9fe4-f3fab859a4e7
# 42359  070947f9-ef5b-4ae8-894c-9d4e51568e75
# ...

# %%
print("Entries with no abstracts:", df_ntd['bibcite_abst_e__value'].isna().sum())
print("Entries with abstracts:", df_ntd['bibcite_abst_e__value'].notna().sum())
df_ntd_nona = df_ntd[df_ntd['bibcite_abst_e__value'].notna()]
# Out:
# Entries with abstracts: 16928
# Entries with no abstracts: 25435

# %%
df_ntd_nona['bibcite_type'].value_counts()
# Out:
# journal_article           23221
# report                      756
# book_chapter                434
# book                        343
# thesis                      314
# miscellaneous               155
# conference_proceedings       43
# web_service                  37
# web_resource                 26
# legal_ruling                 21
# journal                      18
# fact_sheet                   12
# audiovisual                  11
# conference_paper              9
# web_article                   7
# government_report             6
# multimedia                    5
# website                       5
# artwork                       4
# presentation                  2
# newspaper_article             2
# classical                     1
# web_project_page              1
# magazine_article              1
# guidelines                    1
# Name: bibcite_type, dtype: int64

# %%
df_ntd_nona['bibcite_year'].value_counts()
# Out:
# 2024.0    1685
# 2016.0    1433
# 2023.0    1390
# 2020.0    1340
# 2021.0    1301
#           ...
# 1912.0       1
# 1959.0       1
# 1961.0       1
# 1933.0       1
# 1910.0       1
# Name: bibcite_year, Length: 89, dtype: int64

# %% [markdown]
# ### Publication years

# %%
# 1) Copy & build your custom bins
df = df_ntd_nona.copy()
years   = df['bibcite_year']
min_y, max_y = years.min(), years.max()

# 200-year bins up to 1950
start_200 = (min_y // 200) * 200
bins_pre  = np.arange(start_200, 1950, 200)

# 5-year bins from 1950 onward
bins_post = np.arange(1951, max_y + 5, 5)

bins = np.unique(np.concatenate([bins_pre, bins_post]))
labels = [f"{int(bins[i])}–{int(bins[i+1] - 1)}" 
          for i in range(len(bins)-1)]

df['year_group'] = pd.cut(
    df['bibcite_year'],
    bins=bins,
    right=False,
    labels=labels
)

# 2) Group by your year bins & the new column
counts = (
    df
    .groupby(['year_group', 'field_domain_access_target_id'])
    .size()
    .unstack(fill_value=0)
)

# 3) Collapse low-count intervals into "Other Years"
threshold = 100
total_per_interval = counts.sum(axis=1)
low_bins = total_per_interval[total_per_interval < threshold].index

counts_lumped = counts.copy()
counts_lumped.index = counts_lumped.index.where(
    ~counts_lumped.index.isin(low_bins),
    'Other Years'
)
counts_final = counts_lumped.groupby(counts_lumped.index).sum()

# 4) (Optional) Only keep the top N access targets, lump the rest into "Other"
top_n = 5
top_cols = counts_final.sum().sort_values(ascending=False).head(top_n).index.tolist()
others = [c for c in counts_final.columns if c not in top_cols]

counts_final['Other'] = counts_final[others].sum(axis=1)
counts_final = counts_final[top_cols + ['Other']]

# 5) Plot as a stacked bar chart
order = ['Other Years'] + sorted(
    [i for i in counts_final.index if i!='Other Years'],
    key=lambda s: int(s.split('–')[0])
)
counts_final = counts_final.reindex(order)

ax = counts_final.plot(
    kind='bar',
    stacked=True,
    figsize=(12, 6),
    edgecolor='black'
)

ax.set_xlabel('Year interval')
ax.set_ylabel('Count')
ax.set_title('Publications by Year Group and Access Target (stacked)')
ax.legend(title='field_domain_access_target_id', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1) Copy and filter out years below 300
df = df_ntd_nona.copy()
df['bibcite_year'] = (
    pd.to_numeric(df['bibcite_year'], errors='coerce')
      .astype('Int64')
)
df = df[df['bibcite_year'] >= 1965]

# 2) Group by single year & access target, pivot to wide form
counts_per_year = (
    df
    .groupby(['bibcite_year', 'field_domain_access_target_id'])
    .size()
    .unstack(fill_value=0)
)

# 3) (Optional) Keep only top N access targets + lump the rest
top_n = 5
top_cols = counts_per_year.sum().sort_values(ascending=False).head(top_n).index.tolist()
other_cols = [c for c in counts_per_year.columns if c not in top_cols]

counts_per_year['Other'] = counts_per_year[other_cols].sum(axis=1)
counts_per_year = counts_per_year[top_cols + ['Other']]

# 4) Plot as a stacked bar chart
ax = counts_per_year.plot(
    kind='bar',
    stacked=True,
    figsize=(14, 6),
    edgecolor='black'
)

ax.set_xlabel('Publication Year')
ax.set_ylabel('Count')
ax.set_title('Publications by Year and Access Target')
ax.legend(title='Access Target', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Disease distribution

# %%
# 1) Flatten the 'Disease' column into a list of diseases
disease_list = []
for cell in df_ntd_nona['Disease']:
    if pd.isna(cell):
        continue
    # parse stringified lists back to Python lists
    if isinstance(cell, str):
        try:
            items = ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            continue
    elif isinstance(cell, list):
        items = cell
    else:
        continue
    disease_list.extend(items)

# 2) Count each disease
counts = pd.Series(disease_list).value_counts()

# 3) Sort descending (optional, for nicer bars left-to-right)
counts = counts.sort_values(ascending=False)

# 4) Plot with matplotlib (no custom colors)
plt.figure(figsize=(12, 6))
plt.bar(counts.index, counts.values)
plt.xlabel('Disease')
plt.ylabel('Count')
plt.title('Counts of Each Disease in the Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# 1) Parse Diseases into lists
def parse_diseases(cell):
    if pd.isna(cell):
        return []
    if isinstance(cell, list):
        return cell
    if isinstance(cell, str):
        try:
            return ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            return []
    return []

df = df_ntd_nona.copy()
df['disease_list'] = df['Disease'].apply(parse_diseases)

# 2) Explode to one (year, disease) per row
df_exp = (
    df[['bibcite_year', 'disease_list']]
      .explode('disease_list')
      .dropna(subset=['disease_list'])
)

# 3) Filter out outlier years < 300
df_exp = df_exp[df_exp['bibcite_year'] >= 300]

# 4) Pivot to get yearly counts by disease
yearly_counts = (
    df_exp
      .groupby(['bibcite_year', 'disease_list'])
      .size()
      .unstack(fill_value=0)
      .sort_index()
)

# 5) Select top N diseases overall
top_n = 10
top_diseases = yearly_counts.sum().nlargest(top_n).index
yearly_top = yearly_counts[top_diseases]

# 6) Plot lines with smaller markers
plt.figure(figsize=(12, 6))
for disease in top_diseases:
    plt.plot(
        yearly_top.index,
        yearly_top[disease],
        marker='o',
        markersize=4,
        linestyle='-',
        label=disease
    )

plt.xlabel('Publication Year')
plt.ylabel('Number of Publications')
plt.title('Yearly Publication Counts by Disease (Top 10)')
plt.legend(title='Disease', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1) Parse Diseases into lists
def parse_diseases(cell):
    if pd.isna(cell):
        return []
    if isinstance(cell, list):
        return cell
    if isinstance(cell, str):
        try:
            return ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            return []
    return []

df = df_ntd_nona.copy()
df['disease_list'] = df['Disease'].apply(parse_diseases)

# 2) Explode to one (year, disease) per row
df_exp = (
    df[['bibcite_year', 'disease_list']]
      .explode('disease_list')
      .dropna(subset=['disease_list'])
)

# 3) Filter out outlier years < 300
df_exp = df_exp[df_exp['bibcite_year'] >= 1960]

# 4) Pivot to get yearly counts by disease
yearly_counts = (
    df_exp
      .groupby(['bibcite_year', 'disease_list'])
      .size()
      .unstack(fill_value=0)
      .sort_index()
)

# 5) Select top N diseases overall
top_n = 10
top_diseases = yearly_counts.sum().nlargest(top_n).index
yearly_top = yearly_counts[top_diseases]

# 6) Plot lines with smaller markers
plt.figure(figsize=(12, 6))
for disease in top_diseases:
    plt.plot(
        yearly_top.index,
        yearly_top[disease],
        marker='o',
        markersize=4,
        linestyle='-',
        label=disease
    )

plt.xlabel('Publication Year')
plt.ylabel('Number of Publications')
plt.title('Yearly Publication Counts by Disease (Top 10)')
plt.legend(title='Disease', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1) Parse Diseases into lists
def parse_diseases(cell):
    if pd.isna(cell):
        return []
    if isinstance(cell, list):
        return cell
    if isinstance(cell, str):
        try:
            return ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            return []
    return []

df = df_ntd_nona.copy()
df['disease_list'] = df['Disease'].apply(parse_diseases)

# 2) Explode to one (year, disease) per row
df_exp = (
    df[['bibcite_year', 'disease_list']]
      .explode('disease_list')
      .dropna(subset=['disease_list'])
)

# 3) Filter out outlier years < 300 (or use your 1960 cutoff)
df_exp = df_exp[df_exp['bibcite_year'] >= 1960]

# 4) Pivot to get yearly counts by disease
yearly_counts = (
    df_exp
      .groupby(['bibcite_year', 'disease_list'])
      .size()
      .unstack(fill_value=0)
      .sort_index()
)

# 5) Pick top N diseases but exclude the very largest one
top_n = 5
totals = yearly_counts.sum(axis=0).sort_values(ascending=False)

# drop the overall largest
totals = totals.drop(totals.index[0])

# now take the next top_n
top_diseases = totals.head(top_n).index.tolist()

yearly_top = yearly_counts[top_diseases]

# 6) Plot lines for those top N (excluding the largest)
plt.figure(figsize=(12, 6))
for disease in top_diseases:
    plt.plot(
        yearly_top.index,
        yearly_top[disease],
        marker='o',
        markersize=4,
        linestyle='-',
        label=disease
    )

plt.xlabel('Publication Year')
plt.ylabel('Number of Publications')
plt.title(f'Yearly Publication Counts by Disease (top {top_n} excluding the largest)')
plt.legend(title='Disease', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regions

# %%
# 1) Flatten the 'Disease' column into a list of diseases
disease_list = []
for cell in df_ntd_nona['Type4']:
    if pd.isna(cell):
        continue
    # parse stringified lists back to Python lists
    if isinstance(cell, str):
        try:
            items = ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            continue
    elif isinstance(cell, list):
        items = cell
    else:
        continue
    disease_list.extend(items)

# 2) Count each disease
counts = pd.Series(disease_list).value_counts()

# 3) Sort descending (optional, for nicer bars left-to-right)
counts = counts.sort_values(ascending=False)

# 4) Plot with matplotlib (no custom colors)
plt.figure(figsize=(12, 6))
plt.bar(counts.index, counts.values)
plt.xlabel('Regions')
plt.ylabel('Count')
plt.title('Counts of Each Disease in the Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# 1) Flatten the 'Disease' column into a list of diseases
disease_list = []
for cell in df_ntd_nona['Type4']:
    if pd.isna(cell):
        continue
    # parse stringified lists back to Python lists
    if isinstance(cell, str):
        try:
            items = ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            continue
    elif isinstance(cell, list):
        items = cell
    else:
        continue
    disease_list.extend(items)

# 2) Count each disease
counts = pd.Series(disease_list).value_counts()

# 3) Sort descending (optional, for nicer bars left-to-right)
counts = counts.sort_values(ascending=False)

counts = counts[:30]

# 4) Plot with matplotlib (no custom colors)
plt.figure(figsize=(12, 6))
plt.bar(counts.index, counts.values)
plt.xlabel('Regions')
plt.ylabel('Count')
plt.title('Counts of top 30 Regions (Type4) in the Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cross-cutting issues

# %%
# 1) Flatten the 'Disease' column into a list of diseases
disease_list = []
for cell in df_ntd_nona['Type3']:
    if pd.isna(cell):
        continue
    # parse stringified lists back to Python lists
    if isinstance(cell, str):
        try:
            items = ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            continue
    elif isinstance(cell, list):
        items = cell
    else:
        continue
    disease_list.extend(items)

# 2) Count each disease
counts = pd.Series(disease_list).value_counts()

# 3) Sort descending (optional, for nicer bars left-to-right)
counts = counts.sort_values(ascending=False)

# 4) Plot with matplotlib (no custom colors)
plt.figure(figsize=(12, 6))
plt.bar(counts.index, counts.values)
plt.xlabel('Regions')
plt.ylabel('Count')
plt.title('Counts of Each Cross-cutting issue in the Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# 1) Flatten the 'Disease' column into a list of diseases
disease_list = []
for cell in df_ntd_nona['Type3']:
    if pd.isna(cell):
        continue
    # parse stringified lists back to Python lists
    if isinstance(cell, str):
        try:
            items = ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            continue
    elif isinstance(cell, list):
        items = cell
    else:
        continue
    disease_list.extend(items)

# 2) Count each disease
counts = pd.Series(disease_list).value_counts()

# 3) Sort descending (optional, for nicer bars left-to-right)
counts = counts.sort_values(ascending=False)
counts = counts[:30]
# 4) Plot with matplotlib (no custom colors)
plt.figure(figsize=(12, 6))
plt.bar(counts.index, counts.values)
plt.xlabel('Regions')
plt.ylabel('Count')
plt.title('Counts of Top 30 Cross-cutting issue in the Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Keywords

# %%
# 1) Helper to parse your Keywords cell into a Python list
def parse_keywords(cell):
    if pd.isna(cell):
        return []
    # If it’s already a list, just return it
    if isinstance(cell, list):
        return cell
    # If it’s a string, try to literal_eval; otherwise fallback to splitting on common delimiters
    if isinstance(cell, str):
        try:
            return ast.literal_eval(cell)
        except (ValueError, SyntaxError):
            # e.g. "kw1; kw2, kw3" or "kw1,kw2"
            parts = re.split(r'[;,]', cell)
            return [p.strip() for p in parts if p.strip()]
    return []

# 2) Copy & parse into a new list-column
df = df_ntd_nona.copy()
df['keyword_list'] = df['Keywords'].apply(parse_keywords)

# 3) Explode so each row is one keyword
df_kw = (
    df[['keyword_list']]
      .explode('keyword_list')
      .dropna(subset=['keyword_list'])
)

# 4) Count frequencies
kw_counts = df_kw['keyword_list'].value_counts()

# 5) Build & display the word cloud
#    (you can adjust width/height/background_color as you like)
wc = WordCloud(
    width=1600,            # double the width
    height=800,            # double the height
    max_words=300,         # show at most 100 words
    background_color='white',
    random_state=2137
)

wc.generate_from_frequencies(kw_counts.to_dict())

# 6) Plot at high DPI for sharpness
plt.figure(figsize=(16, 8), dpi=200)  # DPI=200 gives much sharper output
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Keyword Word Cloud (top 100)', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # PubMed data
# The dataset is too big so it has to be processed in chunks. I do this a couple times, although I could in one just go, as I was exploring it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter,defaultdict
from tqdm import tqdm
import os

# %%
filename = 'H:/Datasets/pubmed_full.csv'

# Read only the header and a few rows
df_preview = pd.read_csv(filename, nrows=5)

# Show the column names
print(df_preview.columns.tolist())
df_preview
# Out:
# ['pmid', 'title', 'abstract', 'authors', 'language', 'year', 'month', 'publication_type', 'country', 'agency', 'mesh_terms', 'doi']
#    pmid                                              title  abstract  \
# 0     1  Formate assay in body fluids: application in m...       NaN
# 1     2  Delineation of the intimate details of the bac...       NaN
# 2     3  Metal substitutions incarbonic anhydrase: a ha...       NaN
# 3     4  Effect of chloroquine on cultured fibroblasts:...       NaN
# 4     5  Atomic models for the polypeptide backbones of...       NaN
#
#                                          authors language  year  month  \
# 0  A B Makar; K E McMartin; M Palese; T R Tephly      eng  1976      1
# 1                            K S Bose; R H Sarma      eng  1976      1
# 2                          R J Smith; R G Bryant      eng  1976      1
# 3     U N Wiesmann; S DiDonato; N N Herschkowitz      eng  1976      1
# ...

# %%
# Settings
chunksize = 1_000_000
year_column = 'year'  # Update this after inspecting columns

year_counts = Counter()

# Initialize tqdm without total
with pd.read_csv(filename, chunksize=chunksize, usecols=[year_column]) as reader:
    for chunk in tqdm(reader, desc="Processing chunks"):
        chunk[year_column] = pd.to_numeric(chunk[year_column], errors='coerce').astype('Int64')
        filtered_chunk = chunk.dropna(subset=[year_column])
        year_counter = filtered_chunk[year_column].value_counts()
        year_counts.update(year_counter.to_dict())

# Step 4: Convert results to DataFrame
df_year_counts = pd.DataFrame.from_dict(year_counts, orient='index', columns=['count'])
df_year_counts.index.name = 'year'
df_year_counts = df_year_counts.sort_index()
# Out:
# Processing chunks: 37it [03:55,  6.36s/it]

# %%
# Step 5: Plot
ax = df_year_counts.plot(
    kind='bar',
    figsize=(14, 6),
    legend=False,
    edgecolor='black'
)
ax.set_xlabel('Publication Year')
ax.set_ylabel('Number of Papers')
ax.set_title('Number of PubMed Papers per Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The data export comes from the first days of 2025, so it does not have many papers in that year yet. It also uses 0 to denote papers with no assigned publication year, like infoNTD.

# %%
total_rows = 38_000_000  

# Initialize counters
missing_abstract_count = 0
language_counter = Counter()

# Process chunks with tqdm
with pd.read_csv(filename, chunksize=chunksize, usecols=['abstract', 'language']) as reader:
    for chunk in tqdm(reader, total=total_rows // chunksize + 1, desc="Analyzing chunks"):
        # Count missing abstracts
        missing_abstract_count += chunk['abstract'].isna().sum()
        
        # Count language values
        language_counts = chunk['language'].value_counts(dropna=True)
        language_counter.update(language_counts.to_dict())


# Convert language counts to DataFrame for display
df_language_counts = (
    pd.DataFrame.from_dict(language_counter, orient='index', columns=['count'])
    .sort_values(by='count', ascending=False)
)
# Out:
# Analyzing chunks:  95%|█████████▍| 37/39 [08:48<00:28, 14.29s/it]

# %%
df_language_counts.to_csv("Aggregates/language_counts_Pubmed.csv")

# %%
# Show results
print(f"\nTotal missing abstracts: {missing_abstract_count:,}")
print("\nLanguage distribution (top 20):")
print(df_language_counts.head(20))
# Out:
# Total missing abstracts: 11,274,956
#
# Language distribution (top 20):
#         count
# eng  31723931
# ger    898256
# fre    753172
# rus    700600
# jpn    435682
# chi    362115
# spa    344734
# ita    302532
# und    238470
# pol    171719
# cze     89931
# por     89296
# dut     70280
# dan     57070
# swe     56528
# hun     44754
# nor     39435
# rum     28304
# bul     22591
# hrv     19687

# %%
top_languages = df_language_counts

# Plot
ax = top_languages.plot(
    kind='bar',
    figsize=(12, 6),
    legend=False,
    edgecolor='black'
)

ax.set_xlabel('Language')
ax.set_ylabel('Number of Papers')
ax.set_title('Top 20 Languages in PubMed Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_languages = df_language_counts.head(20)

# Plot
ax = top_languages.plot(
    kind='bar',
    figsize=(12, 6),
    legend=False,
    edgecolor='black'
)

ax.set_xlabel('Language')
ax.set_ylabel('Number of Papers')
ax.set_title('Top 20 Languages in PubMed Dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
filename = 'H:/Datasets/pubmed_full.csv'
chunksize = 1_000_000
total_rows = 38_000_000 
year_column = 'year'

# Output folder
output_dir = 'Aggregates'
os.makedirs(output_dir, exist_ok=True)

# Track counts: {year: Counter of term}
agg_publication_type = defaultdict(Counter)
agg_agency = defaultdict(Counter)
agg_mesh_terms = defaultdict(Counter)

# Process in chunks
usecols = [year_column, 'publication_type', 'agency', 'mesh_terms']
with pd.read_csv(filename, chunksize=chunksize, usecols=usecols) as reader:
    for chunk in tqdm(reader, total=total_rows // chunksize + 1, desc="Processing for aggregation"):
        chunk[year_column] = pd.to_numeric(chunk[year_column], errors='coerce').astype('Int64')
        chunk = chunk.dropna(subset=[year_column])

        for _, row in chunk.iterrows():
            year = row[year_column]

            def update_counter(column_name, counter_dict):
                values = row[column_name]
                if pd.notna(values):
                    for val in str(values).split(';'):
                        val = val.strip()
                        if val:
                            counter_dict[year][val] += 1

            update_counter('publication_type', agg_publication_type)
            update_counter('agency', agg_agency)
            update_counter('mesh_terms', agg_mesh_terms)

# Helper to convert defaultdict(Counter) to DataFrame
def counter_to_df(counter_dict):
    all_records = []
    for year, counter in counter_dict.items():
        for term, count in counter.items():
            all_records.append({'year': year, 'term': term, 'count': count})
    return pd.DataFrame(all_records)

# Convert and save
counter_to_df(agg_publication_type).to_csv(f"{output_dir}/publication_type_by_year.csv", index=False)
counter_to_df(agg_agency).to_csv(f"{output_dir}/agency_by_year.csv", index=False)
counter_to_df(agg_mesh_terms).to_csv(f"{output_dir}/mesh_terms_by_year.csv", index=False)

print("Aggregation complete. Files saved in the 'Aggregates' folder.")
# Out:
# ...
# Processing for aggregation:  13%|█▎        | 5/39 [06:00<40:28, 71.41s/it]c:\Users\user1\anaconda3\Lib\site-packages\tqdm\std.py:1181: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   for obj in iterable:
# Processing for aggregation:  31%|███       | 12/39 [14:46<33:24, 74.22s/it]c:\Users\user1\anaconda3\Lib\site-packages\tqdm\std.py:1181: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   for obj in iterable:
# Processing for aggregation:  33%|███▎      | 13/39 [15:55<31:22, 72.41s/it]c:\Users\user1\anaconda3\Lib\site-packages\tqdm\std.py:1181: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   for obj in iterable:
# Processing for aggregation:  95%|█████████▍| 37/39 [43:15<02:20, 70.15s/it]
# Aggregation complete. Files saved in the 'Aggregates' folder.

# %%
df_pubtype = pd.read_csv("Aggregates/publication_type_by_year.csv")

df_pubtype = df_pubtype[df_pubtype['year'] >= 100]

# Pivot to wide format: years as index, terms as columns
df_pubtype_pivot = df_pubtype.pivot_table(index='year', columns='term', values='count', fill_value=0)

# Optional: keep top N most common publication types
top_pubtypes = df_pubtype.groupby('term')['count'].sum().sort_values(ascending=False).head(10).index
df_pubtype_pivot = df_pubtype_pivot[top_pubtypes]

# Plot
df_pubtype_pivot.plot(figsize=(14, 6))
plt.title("Publication Types Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend(title="Publication Type", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_agency = pd.read_csv("Aggregates/agency_by_year.csv")
df_agency = df_agency[df_agency['year'] >= 100]
# Pivot to wide format
df_agency_pivot = df_agency.pivot_table(index='year', columns='term', values='count', fill_value=0)

# Optional: top N agencies
top_agencies = df_agency.groupby('term')['count'].sum().sort_values(ascending=False).head(10).index
df_agency_pivot = df_agency_pivot[top_agencies]

# Plot
df_agency_pivot.plot(figsize=(14, 6))
plt.title("Agencies Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend(title="Agency", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_mesh = pd.read_csv("Aggregates/mesh_terms_by_year.csv")
df_mesh = df_mesh[df_mesh['year'] >= 100]
# Get top 10 MeSH terms
top_mesh_terms = df_mesh.groupby('term')['count'].sum().sort_values(ascending=False).head(10).index

# Filter and pivot
df_mesh_top = df_mesh[df_mesh['term'].isin(top_mesh_terms)]
df_mesh_pivot = df_mesh_top.pivot_table(index='year', columns='term', values='count', fill_value=0)

# Plot
df_mesh_pivot.plot(figsize=(14, 6))
plt.title("Top 10 MeSH Terms Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend(title="MeSH Term", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
def plot_mesh_terms_over_time(selected_terms):
    df_mesh = pd.read_csv("Aggregates/mesh_terms_by_year.csv")
    df_filtered = df_mesh[df_mesh['term'].isin(selected_terms)]
    df_pivot = df_filtered.pivot_table(index='year', columns='term', values='count', fill_value=0)

    df_pivot.plot(figsize=(14, 6))
    plt.title(f"Selected MeSH Terms Over Time")
    plt.xlabel("Year")
    plt.ylabel("Count")
    plt.legend(title="MeSH Term", bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# Example usage:
plot_mesh_terms_over_time(['Leprosy, Borderline', 'Leprosy, Lepromatous','Leprosy, Tuberculoid','Leprosy, Paucibacillary','Leprosy, Multibacillary'])

# %% [markdown]
# # Article co-occurence
#
# ## DOI
# First let's see how many we can match based on the DOI. We know we are missing some DOIs, so this will not be complete.
#
# (Imports appear multiple times as I run the code in different sessions)

# %%
import pandas as pd
import os
import re
from tqdm import tqdm

# %%
# 1) Build a set of all non‐null DOIs from df_ntd
doi_set = set(df_ntd['bibcite_doi'].dropna().astype(str))

# 2) Iterate over the large CSV in chunks (38 chunks of 1 million rows),
#    keeping all columns but filtering on DOI, with a progress bar.
filename = 'H:/Datasets/pubmed_full.csv'
chunksize = 1_000_000
n_chunks = 38

matched_chunks = []  # we’ll append each filtered chunk here

# Read ALL columns by default (don’t specify usecols), force dtype=str for consistency
with pd.read_csv(filename, dtype=str, chunksize=chunksize) as reader:
    for chunk in tqdm(reader, total=n_chunks, desc="Processing chunks"):
        # Filter rows where chunk['doi'] exists in doi_set
        filtered = chunk[chunk['doi'].isin(doi_set)]
        if not filtered.empty:
            matched_chunks.append(filtered)

# Concatenate every “hit” chunk into one DataFrame
if matched_chunks:
    df_large_hits = pd.concat(matched_chunks, ignore_index=True)
else:
    # In case there are zero hits, create an empty DataFrame
    df_large_hits = pd.DataFrame(columns=reader._engine.names)

# 3) Merge back to df_ntd so that you end up with all columns from both sides
df_doi_matched = (
    df_large_hits
      .merge(
         df_ntd,
         left_on='doi',
         right_on='bibcite_doi',
         how='inner',
         suffixes=('_large', '_small')
      )
)

# 4) Save the merged result
out_path = os.path.join('Aggregates/doi_matches.csv')
df_doi_matched.to_csv(out_path, index=False)
print(f"Saved exact‐DOI matches (all columns) to:\n  {out_path}")
# Out:
# ...
# Processing chunks:  97%|█████████▋| 37/38 [13:42<00:22, 22.23s/it]
# Saved exact‐DOI matches (all columns) to:
#   Aggregates/doi_matches.csv

# %%
df_test = pd.read_csv('Aggregates/doi_matches.csv')
df_test.shape
# Out:
# (9911, 41)

# %%
df_ntd[~df_ntd['bibcite_doi'].isna()].shape
# Out:
# (20577, 29)

# %% [markdown]
# Looking by DOI, we managed to find 9.9k papers that appear both in PubMed and in InfoNTD databases. This is already good, but I would want to have matches for all of the options. Let's try title matching.
# ## Title

# %%
# ─── PREP: ensure `df_ntd` is in memory with columns 'itle' and 'bibcite_year' (if needed) ───
# Drop any rows without a title, then normalize:
df_small = df_ntd.dropna(subset=['title']).copy()
df_small['norm_title_small'] = (
    df_small['title']
      .astype(str)
      .str.lower()
      .str.replace(r'\W+', ' ', regex=True)
      .str.strip()
)

# Build a set of all normalized titles from df_small
title_set = set(df_small['norm_title_small'])


# Iterate over the large CSV in chunks, normalize its titles, and keep only exact matches
filename = 'H:/Datasets/pubmed_full.csv'
chunksize = 1_000_000
n_chunks = 38

matched_chunks = []

with pd.read_csv(filename, dtype=str, chunksize=chunksize) as reader:
    for chunk in tqdm(reader, total=n_chunks, desc="Matching by normalized title"):
        # Drop rows with no title
        chunk = chunk.dropna(subset=['title']).copy()
        if chunk.empty:
            continue

        # Normalize the large‐DF titles
        chunk['norm_title_large'] = (
            chunk['title']
              .astype(str)
              .str.lower()
              .str.replace(r'\W+', ' ', regex=True)
              .str.strip()
        )

        # Filter rows where normalized title is in our small‐DF set
        filtered = chunk[chunk['norm_title_large'].isin(title_set)]
        if not filtered.empty:
            matched_chunks.append(filtered)

# Concatenate all matched chunks (if any)
if matched_chunks:
    df_large_hits = pd.concat(matched_chunks, ignore_index=True)
else:
    # If no matches, create an empty DataFrame with the same columns as a chunk
    df_large_hits = pd.DataFrame(columns=reader._engine.names + ['norm_title_large'])

# Merge back to df_small on normalized title
df_title_matched = (
    df_large_hits
      .merge(
         df_small,
         left_on='norm_title_large',
         right_on='norm_title_small',
         how='inner',
         suffixes=('_large', '_small')
      )
)

# Save the result
out_path = os.path.join('Aggregates/title_exact_norm_matches.csv')
df_title_matched.to_csv(out_path, index=False)
print(f"Saved exact normalized title matches to:\n  {out_path}")
# Out:
# Matching by normalized title:  97%|█████████▋| 37/38 [20:06<00:32, 32.62s/it]
# Saved exact normalized title matches to:
#   Aggregates/title_exact_norm_matches.csv

# %%
df_test = pd.read_csv('Aggregates/title_exact_norm_matches.csv')
df_test.shape
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_37880\785538882.py:1: DtypeWarning: Columns (2,9,10,11,20,21,22,23,24,35,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('Aggregates/title_exact_norm_matches.csv')
# (1015703, 43)

# %% [markdown]
# For some titles there were many matches, which makes seanse, as some are just "Editorial" or "Case". I will get rid of these duplicates and assume they exist in the database.

# %%
# Path to the previously created matches file
aggregates_dir = os.path.join(os.getcwd(), 'Aggregates')
in_path = os.path.join(aggregates_dir, 'title_exact_norm_matches.csv')
out_path = os.path.join(aggregates_dir, 'title_exact_norm_matches_dedup.csv')


# Load the existing matches (≈1M+ rows)
df_matches = pd.read_csv(in_path)

# Deduplicate so that each small‐dataset title appears only once.
# We drop duplicates based on 'norm_title_small' (i.e., the normalized bibcite_title).
n_before = len(df_matches)
df_dedup = df_matches.drop_duplicates(subset=['bib_id', 'bibcite_type', 'uuid', 'bibcite_title', 'bibcite_year', 'Keywords','field_domain_access_target_id'], keep='first')
n_after = len(df_dedup)

print(f"Rows before deduplication: {n_before}")
print(f"Rows after deduplication:  {n_after}")

# Save the deduplicated result
out_path = os.path.join(aggregates_dir, 'title_exact_norm_matches_dedup.csv')
df_dedup.to_csv(out_path, index=False)
print(f"Saved deduplicated matches to:\n  {out_path}")
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_37880\3556100378.py:8: DtypeWarning: Columns (2,9,10,11,20,21,22,23,24,35,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_matches = pd.read_csv(in_path)
# Rows before deduplication: 1015703
# Rows after deduplication:  30968
# Saved deduplicated matches to:
#   c:\Users\user1\Desktop\Studia\Masters Thesis\Thesis Coding\Aggregates\title_exact_norm_matches_dedup.csv

# %% [markdown]
# ## Seeing how many remain unmatched after both approaches

# %%
# 1) Normalize df_ntd key columns: ensure all are strings and fillna('')
key_cols = ['bib_id', 'bibcite_title', 'bibcite_year']
df_ntd[key_cols] = df_ntd[key_cols].fillna('').astype(str)

# 2) Paths to matched-by-DOI and matched-by-Title files
aggregates_dir = os.path.join(os.getcwd(), 'Aggregates')
doi_path       = os.path.join(aggregates_dir, 'doi_matches.csv')
title_path     = os.path.join(aggregates_dir, 'title_exact_norm_matches_dedup.csv')

# 3) Load both match files, ensuring their key columns match df_ntd’s types
df_doi_matched   = pd.read_csv(doi_path,   dtype=str)
df_title_matched = pd.read_csv(title_path, dtype=str)

# 4) For each matched DataFrame, extract the set of tuples of the six key columns
def build_key_set(df, cols):
    # Fill missing with '' and cast to str (in case dtype was different)
    df_subset = df[cols].fillna('').astype(str)
    return set(zip(*(df_subset[col] for col in cols)))

set_doi   = build_key_set(df_doi_matched,   key_cols)
set_title = build_key_set(df_title_matched, key_cols)

# 5) Report individual match‐set sizes
print(f"Unique rows matched by DOI (using 6‐col key):   {len(set_doi)}")
print(f"Unique rows matched by Title (using 6‐col key): {len(set_title)}")

# 6) Compute union of the two sets
all_matched = set_doi.union(set_title)
print(f"Total unique df_ntd‐rows matched (DOI ∪ Title, 6‐col key): {len(all_matched)}")

# 7) Filter df_ntd to keep only rows whose 6‐col tuple is NOT in `all_matched`
#    Build a Series of tuples for each row in df_ntd
ntd_tuples = list(zip(*(df_ntd[col] for col in key_cols)))
mask_unmatched = [tpl not in all_matched for tpl in ntd_tuples]
df_unmatched = df_ntd[mask_unmatched].copy()

print(f"Rows in df_ntd not matched by either method: {len(df_unmatched)}")

# 8) Save the unmatched rows for inspection
out_unmatched = os.path.join(aggregates_dir, 'df_ntd_unmatched.csv')
df_unmatched.to_csv(out_unmatched, index=False)
print(f"Saved unmatched df_ntd rows to:\n  {out_unmatched}")

# 9) Display the unmatched DataFrame for visual inspection
df_unmatched
# Out:
# Unique rows matched by DOI (using 6‐col key):   9315
# Unique rows matched by Title (using 6‐col key): 29901
# Total unique df_ntd‐rows matched (DOI ∪ Title, 6‐col key): 30123
# Rows in df_ntd not matched by either method: 11186
# Saved unmatched df_ntd rows to:
#   c:\Users\user1\Desktop\Studia\Masters Thesis\Thesis Coding\Aggregates\df_ntd_unmatched.csv
#        Unnamed: 0    bib_id     bibcite_type  \
# 0               0       6.0           thesis
# 144           144     174.0  journal_article
# 369           369     398.0  journal_article
# 373           373     402.0  journal_article
# 1297         1297    1335.0  journal_article
# ...           ...       ...              ...
# 42358       42358  102107.0  journal_article
# 42359       42359  102108.0  journal_article
# 42360       42360  102109.0  journal_article
# 42361       42361  102110.0  journal_article
# 42362       42362  102111.0           report
#
#                                        uuid  \
# ...

# %% [markdown]
# Checking some DOIs - an issue is similar titles - sometimes the title in PubMed is shorter, but the paper is the same.

# %%
df_unmatched['bibcite_year'].value_counts()
# Out:
# 2024.0    2029
# 2023.0     834
# 2020.0     662
# 2017.0     643
# 2022.0     599
#           ...
# 1857.0       1
# 1904.0       1
# 1847.0       1
# 1868.0       1
# 1917.0       1
# Name: bibcite_year, Length: 135, dtype: int64
